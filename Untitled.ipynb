# %% [markdown]
# # 导入库

# %%
import pandas as pd

# %% [markdown]
# # 导入查看数据

# %%
df1 = pd.read_csv('GlobalLandTemperaturesByCountry.csv')
df1.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %% [markdown]
# # 以国家分组计算历史平均温度

# %%
# 经查看，数据是从 1750-2013 年的
df1.tail()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 577457  Zimbabwe
# 577458  Zimbabwe
# 577459  Zimbabwe
# 577460  Zimbabwe
# 577461  Zimbabwe

# %%
# 以国家分组计算 1743-2013 年历史平均温度，并查看缺失值的个数，删除缺失值
df3 = df1.groupby('Country')['AverageTemperature'].mean()
display(sum(df3.isnull()))
df3 = df3.dropna()
display(sum(df3.isnull()))
# Out:
# 1
# 0

# %%
df3.head()
# Out:
# Country
# Afghanistan       14.045007
# Africa            24.074203
# Albania           12.610646
# Algeria           22.985112
# American Samoa    26.611965
# Name: AverageTemperature, dtype: float64

# %% [markdown]
# # 绘制地图

# %%
country = list(df3.index)
v = list(df3.values)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

c = Map()
c.add("", [list(z) for z in zip(country, v)], "world")
c.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
c.set_global_opts(
        title_opts=opts.TitleOpts(title="每个国家历史平均温度（摄氏度）"),
        visualmap_opts=opts.VisualMapOpts(max_=30),
    )
c.render('世界历史平均气温.html')
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="0ee8c3e1836d4d42bdc23170b477fd52" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_0ee8c3e1836d4d42bdc23170b477fd52 = echarts.init(
#                     document.getElementById('0ee8c3e1836d4d42bdc23170b477fd52'), 'white', {renderer: 'canvas'});
#                 var option_0ee8c3e1836d4d42bdc23170b477fd52 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Afghanistan",
#                     "value": 14.045007194244608
#                 },
#                 {
#                     "name": "Africa",
#                     "value": 24.07420274551212
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 12.61064592545798
#                 },
#                 {
#                     "name": "Algeria",
#                     "value": 22.985111769059955
#                 },
#                 {
#                     "name": "American Samoa",
#                     "value": 26.611965009208156
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 11.201553063802905
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 21.82454918981486
#                 },
#                 {
#                     "name": "Anguilla",
#                     "value": 26.610491850431465
#                 },
#                 {
#                     "name": "Antigua And Barbuda",
#                     "value": 26.437924256951035
#                 },
#                 {
#                     "name": "Argentina",
#                     "value": 14.621194210526305
#                 },
#                 {
#                     "name": "Armenia",
#                     "value": 8.551647926634773
#                 },
#                 {
#                     "name": "Aruba",
#                     "value": 27.92039022051774
#                 },
#                 {
#                     "name": "Asia",
#                     "value": 7.347892223161453
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 21.624696891191693
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 6.210731838281731
#                 },
#                 {
#                     "name": "Azerbaijan",
#                     "value": 11.175936074918587
#                 },
#                 {
#                     "name": "Bahamas",
#                     "value": 25.12822004008018
#                 },
#                 {
#                     "name": "Bahrain",
#                     "value": 25.93080933465739
#                 },
#                 {
#                     "name": "Baker Island",
#                     "value": 25.372350232798794
#                 },
#                 {
#                     "name": "Bangladesh",
#                     "value": 24.82024278370897
#                 },
#                 {
#                     "name": "Barbados",
#                     "value": 26.45854793863855
#                 },
#                 {
#                     "name": "Belarus",
#                     "value": 5.819288060644335
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 9.48337839545166
#                 },
#                 {
#                     "name": "Belize",
#                     "value": 25.052099776286326
#                 },
#                 {
#                     "name": "Benin",
#                     "value": 27.171999431818186
#                 },
#                 {
#                     "name": "Bhutan",
#                     "value": 11.811878969957082
#                 },
#                 {
#                     "name": "Bolivia",
#                     "value": 20.8772305263158
#                 },
#                 {
#                     "name": "Bonaire, Saint Eustatius And Saba",
#                     "value": 27.173294822627003
#                 },
#                 {
#                     "name": "Bosnia And Herzegovina",
#                     "value": 10.421283954516774
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 21.879296691568843
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 24.699255545286466
#                 },
#                 {
#                     "name": "British Virgin Islands",
#                     "value": 26.336523239099186
#                 },
#                 {
#                     "name": "Bulgaria",
#                     "value": 10.482968414403024
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 28.083506760410998
#                 },
#                 {
#                     "name": "Burma",
#                     "value": 23.70619723953693
#                 },
#                 {
#                     "name": "Burundi",
#                     "value": 20.070990127758442
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 26.65685403576609
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 24.352585590778116
#                 },
#                 {
#                     "name": "Canada",
#                     "value": -5.216658945686897
#                 },
#                 {
#                     "name": "Cape Verde",
#                     "value": 24.185563568376022
#                 },
#                 {
#                     "name": "Cayman Islands",
#                     "value": 26.722504150283953
#                 },
#                 {
#                     "name": "Central African Republic",
#                     "value": 25.28040691642648
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 27.12046628242079
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 9.383473684210513
#                 },
#                 {
#                     "name": "China",
#                     "value": 6.612731031349375
#                 },
#                 {
#                     "name": "Christmas Island",
#                     "value": 25.784654071314534
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 24.716870967741926
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 25.70220930232557
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 24.4629319884726
#                 },
#                 {
#                     "name": "Congo (Democratic Republic Of The)",
#                     "value": 23.77366493955099
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 25

# %% [markdown]
# # 温度走势图

# %%
# 取时间中的年
df1['dt'] = pd.to_datetime(df1['dt']).dt.year
df1.head()
# Out:
#      dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743               4.384                          2.294   Åland
# 1  1743                 NaN                            NaN   Åland
# 2  1744                 NaN                            NaN   Åland
# 3  1744                 NaN                            NaN   Åland
# 4  1744                 NaN                            NaN   Åland

# %%
# 以年份分组计算全球每年的平均温度，缺失值用前一个值填充
df4 = df1.groupby(['dt'])['AverageTemperature'].mean()
df4 = df4.fillna(axis=0,method='ffill')
df4.head()
# Out:
# dt
# 1743    5.184140
# 1744    9.837898
# 1745    1.387125
# 1746    1.387125
# 1747    1.387125
# Name: AverageTemperature, dtype: float64

# %%
x = list(df4.index)[4:]
x = [str(i) for i in x]
y = list(df4.values)[4:]

# %%
import pyecharts.options as opts
from pyecharts.charts import Line


c = Line()
c.add_xaxis(x)
c.add_yaxis("气温（摄氏度）", y,label_opts=opts.LabelOpts(is_show=False))
c.set_global_opts(title_opts=opts.TitleOpts(title="1747-2013年"))
c.render('全球历年温度走势.html')
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="29f38c08a5434613981bce30336ce101" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_29f38c08a5434613981bce30336ce101 = echarts.init(
#                     document.getElementById('29f38c08a5434613981bce30336ce101'), 'white', {renderer: 'canvas'});
#                 var option_29f38c08a5434613981bce30336ce101 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6c14\u6e29\uff08\u6444\u6c0f\u5ea6\uff09",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1747",
#                     1.3871250000000008
#                 ],
#                 [
#                     "1748",
#                     1.3871250000000008
#                 ],
#                 [
#                     "1749",
#                     1.3871250000000008
#                 ],
#                 [
#                     "1750",
#                     9.12935272727273
#                 ],
#                 [
#                     "1751",
#                     9.1673875
#                 ],
#                 [
#                     "1752",
#                     4.413386666666669
#                 ],
#                 [
#                     "1753",
#                     8.870820754716975
#                 ],
#                 [
#                     "1754",
#                     8.822018957345975
#                 ],
#                 [
#                     "1755",
#                     8.530536277602524
#                 ],
#                 [
#                     "1756",
#                     9.17988625592418
#                 ],
#                 [
#                     "1757",
#                     8.993332283464573
#                 ],
#                 [
#                     "1758",
#                     8.130370542635658
#                 ],
#                 [
#                     "1759",
#                     9.261257716049373
#                 ],
#                 [
#                     "1760",
#                     8.532081761006298
#                 ],
#                 [
#                     "1761",
#                     8.940669242658416
#                 ],
#                 [
#                     "1762",
#                     8.517924148606802
#                 ],
#                 [
#                     "1763",
#                     8.086262422360255
#                 ],
#                 [
#                     "1764",
#                     8.84558786936237
#                 ],
#                 [
#                     "1765",
#                     8.503952086553312
#                 ],
#                 [
#                     "1766",
#                     8.620333333333344
#                 ],
#                 [
#                     "1767",
#                     8.208010819165374
#                 ],
#                 [
#                     "1768",
#                     7.87581696428572
#                 ],
#                 [
#                     "1769",
#                     8.441631964809378
#                 ],
#                 [
#                     "1770",
#                     8.608895454545452
#                 ],
#                 [
#                     "1771",
#                     8.429763636363635
#                 ],
#                 [
#                     "1772",
#                     9.105813271604958
#                 ],
#                 [
#                     "1773",
#                     9.080228310502273
#                 ],
#                 [
#                     "1774",
#                     8.403788109756087
#                 ],
#                 [
#                     "1775",
#                     9.307762589928071
#                 ],
#                 [
#                     "1776",
#                     8.210426491994166
#                 ],
#                 [
#                     "1777",
#                     8.102558739255016
#                 ],
#                 [
#                     "1778",
#                     8.707566568047346
#                 ],
#                 [
#                     "1779",
#                     9.231317436661708
#                 ],
#                 [
#                     "1780",
#                     8.83174251497006
#                 ],
#                 [
#                     "1781",
#                     9.09541374269006
#                 ],
#                 [
#                     "1782",
#                     7.793591630591629
#                 ],
#                 [
#                     "1783",
#                     8.957380809595199
#                 ],
#                 [
#                     "1784",
#                     7.977893939393945
#                 ],
#                 [
#                     "1785",
#                     7.753425149700594
#                 ],
#                 [
#                     "1786",
#                     7.9631562499999955
#                 ],
#                 [
#                     "1787",
#                     10.600193333333333
#                 ],
#                 [
#                     "1788",
#                     9.915709141274235
#                 ],
#                 [
#                     "1789",
#                     10.551814578005105
#                 ],
#                 [
#                     "1790",
#                     10.938674934725853
#                 ],
#                 [
#                     "1791",
#                     11.380044554455454
#                 ],
#                 [
#                     "1792",
#                     10.512480964466997
#                 ],
#                 [
#                     "1793",
#                     9.630539215686278
#                 ],
#                 [
#                     "1794",
#                     10.270525730180815
#                 ],
#                 [
#                     "1795",
#                     9.371622881355925
#                 ],
#                 [
#                     "1796",
#                     10.280041184041169
#                 ],
#                 [
#                     "1797",
#                     10.550860313315937
#                 ],
#                 [
#                     "1798",
#                     10.791231578947377
#                 ],
#                 [
#                     "1799",
#                     9.863822164948452
#                 ],
#                 [
#                     "1800",
#                     10.804132051282046
#                 ],
#                 [
#                     "1801",
#                     11.027885416666663
#                 ],
#                 [
#                     "1802",
#                     10.97987532467532
#                 ],
#                 [
#                     "1803",
#                     10.936170370370363
#                 ],
#                 [
#                     "1804",
#                     11.715498203592809
#                 ],
#                 [
#                     "1805",
#                     9.699310299869628
#                 ],
#                 [
#                     "1806",
#                     10.809632812499993
#                 ],
#                 [
#                     "1807",
#                     10.411802371541508
#                 ],
#                 [
#                     "1808",
#                     8.955127688172045
#                 ],
#                 [

# %% [markdown]
# # 建立预测模型

# %%
# 从走势图上看 1888 年之前的走势不太稳定，由于时间过早科学不发达，
# 所以选取 1888 年及之后的数据
index = x.index('1888')
x = x[index:]
x = [int(i) for i in x]
y = y[index:]

# %%
# 使用线性回归模型
from sklearn.linear_model import LinearRegression
import numpy as np
clf = LinearRegression()
x = np.array(x).reshape(126,1) # 将 x,y 重塑为二维矩阵
y = np.array(y).reshape(126,1)
clf.fit(x,y)
display(clf.coef_) # 系数
display(clf.intercept_) # 截距
# Out:
# array([[0.00916559]])
# array([0.89717817])

# %%
# 模型预测 2014-2020 年的全球平均温度
pre = clf.predict([[2014],[2015],[2016],[2017],[2018],[2019],[2020]]) 
pre
# Out:
# array([[19.35668092],
#        [19.36584652],
#        [19.37501211],
#        [19.3841777 ],
#        [19.39334329],
#        [19.40250889],
#        [19.41167448]])

# %%
# 2014-2020 年全球平均温度走势
import pyecharts.options as opts
from pyecharts.charts import Line

x_data = ["2014", "2015", "2016", "2017", "2018", "2019", "2020"]
y_data = [19.35668092,19.36584652,19.3841777,19.39334329,19.40250889,
         19.41167448]


a = Line()
a.set_global_opts(
        tooltip_opts=opts.TooltipOpts(is_show=False),
        xaxis_opts=opts.AxisOpts(type_="category"),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
a.add_xaxis(xaxis_data=x_data)
a.add_yaxis(
        series_name="",
        y_axis=y_data,
        symbol="emptyCircle",
        is_symbol_show=True,
        label_opts=opts.LabelOpts(is_show=False),
    )
a.render('2014-2020年温度.html')
a.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="edd59a22bca44566bd04623f5c32fb87" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_edd59a22bca44566bd04623f5c32fb87 = echarts.init(
#                     document.getElementById('edd59a22bca44566bd04623f5c32fb87'), 'white', {renderer: 'canvas'});
#                 var option_edd59a22bca44566bd04623f5c32fb87 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2014",
#                     19.35668092
#                 ],
#                 [
#                     "2015",
#                     19.36584652
#                 ],
#                 [
#                     "2016",
#                     19.3841777
#                 ],
#                 [
#                     "2017",
#                     19.39334329
#                 ],
#                 [
#                     "2018",
#                     19.40250889
#                 ],
#                 [
#                     "2019",
#                     19.41167448
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017",
#                 "2018",
#                 "2019",
#                 "2020"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_edd59a22bca44566bd04623f5c32fb87.setOption(option_edd59a22bca44566bd04623f5c32fb87);
#         });
#     </script>
